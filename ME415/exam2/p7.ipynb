# %%
# %reset -f
# %load_ext autoreload
# %autoreload 2

import numpy as np
from matplotlib import pyplot as plt

T = 1
V = 1
Vs = 6
omega = np.linspace(10000,20000,100)
Kv = 3691
R = 1.04
I0 = 0.28
I = (Vs - omega / Kv) * (1/R)
Q = (1/Kv) * (I - I0)

Tweird = 1
Vweird = 1
Vsweird = 6
omegaweird = np.linspace(10000,20000,100)
Kvweird = 3691
Rweird = 1.5
I0weird = 0.28
Iweird = (Vsweird - omegaweird / Kvweird) * (1/Rweird)
Qweird = (1/Kvweird) * (Iweird - I0weird)

etaM = Q * omega / (I * Vs)
etaMweird = Qweird * omegaweird / (Iweird * Vsweird)
etaPweird = T * V / (Qweird * omegaweird)
etaP = T * V / (Q * omega)
etaT = T * V / (I * Vs)

plt.plot(omega,etaM,c='orange')
plt.plot(-omega + 25000,etaM,c='blue')
plt.plot(omega,etaMweird,c='red')
plt.plot(-omega + 25000,etaMweird,c='black')
# plt.plot(omega,etaP)
plt.show()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
